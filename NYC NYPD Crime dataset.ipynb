# %%
import pandas as pd #This function import pandas library into your workspace

# %%
df = pd.read_excel("NYPD Complaint Data.xlsx")
df.head()
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 0   238863220           25  MANHATTAN   2021-12-31     21:45:00   2021-12-31
# 1   242870934           46      BRONX   2018-03-16     12:00:00   2022-03-30
# 2   247126072           44      BRONX   2019-11-10     17:00:00   2022-06-24
# 3   238537159           44      BRONX   2022-01-02     08:40:00   2022-01-02
# 4   242411612           73   BROOKLYN   2021-12-01     12:00:00   2022-03-18
#
#   CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  ...  \
# 0     21:50:00        COMPLETED     (null)        670.0  ...
# 1     22:57:00        COMPLETED     (null)          NaN  ...
# 2     19:03:00        COMPLETED     (null)          NaN  ...
# 3     08:50:00        COMPLETED     (null)          NaN  ...
# 4     12:00:00        COMPLETED     (null)          NaN  ...
#
#    TRANSIT_DISTRICT VIC_AGE_GROUP        VIC_RACE VIC_SEX X_COORD_CD  \
# ...

# %%
df.describe()
# Out:
#          CMPLNT_NUM    ADDR_PCT_CD   HOUSING_PSA  JURISDICTION_CODE  \
# count  1.400500e+05  140050.000000  12646.000000      140050.000000
# mean   2.431906e+08      64.278493   6921.339080           0.404727
# std    2.588857e+06      34.755221  13816.672439           4.233591
# min    2.384927e+08       1.000000    218.000000           0.000000
# 25%    2.410055e+08      40.000000    489.000000           0.000000
# 50%    2.432139e+08      66.000000    720.000000           0.000000
# 75%    2.454808e+08     101.000000   1251.000000           0.000000
# max    2.475431e+08     123.000000  64443.000000          97.000000
#
#                KY_CD          PD_CD  TRANSIT_DISTRICT    X_COORD_CD  \
# count  140050.000000  140050.000000       2808.000000  1.400500e+05
# mean      328.283699     394.394223         13.795940  1.005990e+06
# std       176.536813     227.670265         12.533391  2.130622e+04
# min       102.000000     100.000000          1.000000  9.142100e+05
# ...

# %%
df[['BORO_NM']]
# Out:
#           BORO_NM
# 0       MANHATTAN
# 1           BRONX
# 2           BRONX
# 3           BRONX
# 4        BROOKLYN
# ...           ...
# 140045     QUEENS
# 140046  MANHATTAN
# 140047   BROOKLYN
# 140048     QUEENS
# 140049  MANHATTAN
#
# [140050 rows x 1 columns]

# %%
len(df)
# Out:
# 140050

# %%
df.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20252/2518340673.py in <module>
# ----> 1 df.summary()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'summary'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140050 entries, 0 to 140049
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   CMPLNT_NUM                140050 non-null  int64
#  1   ADDR_PCT_CD               140050 non-null  int64
#  2   BORO_NM                   140050 non-null  object
#  3   CMPLNT_FR_DT              140050 non-null  datetime64[ns]
#  4   CMPLNT_FR_TM              140050 non-null  object
#  5   CMPLNT_TO_DT              140050 non-null  datetime64[ns]
#  6   CMPLNT_TO_TM              140050 non-null  object
#  7   CRM_ATPT_CPTD_CD          140050 non-null  object
#  8   HADEVELOPT                140050 non-null  object
#  9   HOUSING_PSA               12646 non-null   float64
#  10  JURISDICTION_CODE         140050 non-null  int64
#  11  JURIS_DESC                140050 non-null  object
#  12  KY_CD                     140050 non-null  int64
# ...

# %%
import seaborn as sns

# %%
rgb_values = sns.color_palette ("Set2",6)

# %%
sns.set_palette("PuBu")
sns.countplot(data=df, x="BORO_NM", order=df["BORO_NM"].value_counts(ascending=True).index)
# Out:
# <AxesSubplot:xlabel='BORO_NM', ylabel='count'>

# %%
sns.scatterplot(data=df, x="Longitude", y="Latitude", hue="LAW_CAT_CD", style="LAW_CAT_CD")
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>
